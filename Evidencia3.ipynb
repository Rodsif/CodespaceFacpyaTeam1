# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodsif/CodespaceFacpyaTeam1/blob/main/Evidencia3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import io

# %%
from google.colab import files

# %%
uploaded = files.upload ()
# Out:
#      <input type="file" id="files-84de5630-c225-481b-824a-ad8a2d6b5dc0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84de5630-c225-481b-824a-ad8a2d6b5dc0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(io.StringIO(uploaded['titanic.csv'].decode('latin-1')))

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# Muestra la forma de un conjunto de datos usando shape

# %%
df.shape
# Out:
# (1310, 14)

# %%
print (len(df))
# Out:
# 1310

# %%
print(df.shape[1])
# Out:
# 14

# %% [markdown]
# Para ver las primeras 5 filas del dataframe

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# Para mostrar las últimas 5 filas del dataframe

# %%
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1305     3.0       0.0      Zabour, Miss. Thamine  female   NaN    1.0    0.0
# 1306     3.0       0.0  Zakarian, Mr. Mapriededer    male  26.5    0.0    0.0
# 1307     3.0       0.0        Zakarian, Mr. Ortin    male  27.0    0.0    0.0
# 1308     3.0       0.0         Zimmerman, Mr. Leo    male  29.0    0.0    0.0
# 1309     NaN       NaN                        NaN     NaN   NaN    NaN    NaN
#
#       ticket     fare cabin embarked boat   body home.dest
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN
# 1309     NaN      NaN   NaN      NaN  NaN    NaN       NaN
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %% [markdown]
# Especificar la columna nombre

# %%
df['name']
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# 1309                                                NaN
# Name: name, Length: 1310, dtype: object

# %%
df['age']
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# 1309        NaN
# Name: age, Length: 1310, dtype: float64

# %%
df['name'],['age']
# Out:
# (0                         Allen, Miss. Elisabeth Walton
#  1                        Allison, Master. Hudson Trevor
#  2                          Allison, Miss. Helen Loraine
#  3                  Allison, Mr. Hudson Joshua Creighton
#  4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                               ...
#  1305                              Zabour, Miss. Thamine
#  1306                          Zakarian, Mr. Mapriededer
#  1307                                Zakarian, Mr. Ortin
#  1308                                 Zimmerman, Mr. Leo
#  1309                                                NaN
#  Name: name, Length: 1310, dtype: object,
#  ['age'])

# %%
df['name'] = df['name'].str.upper()df
